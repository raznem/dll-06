# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1, 1))
display.start()

import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display
import gym
import numpy as np
import cv2

# %%
from stable_baselines.common.policies import MlpLstmPolicy, MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines import ACKTR
from stable_baselines.common import make_vec_env, set_global_seeds

# %%
def evaluate_2(model, num_episodes=100):
    """
    Evaluate a RL agent
    :param model: (BaseRLModel object) the RL Agent
    :param num_episodes: (int) number of episodes
    :return: (float) Mean reward for the given number of episodes
    """
    episode_rewards = []
    obs = env.reset()
    for i in range(num_episodes):
        episode_rewards.append(0.0)
        done = False
        while not done:
            # _states are only useful when using LSTM policies
            action, _states = model.predict(obs)
            obs, reward, done, info = env.step(action)
            reward, done, info = reward[0], done[0], info[0]
            # Stats
            episode_rewards[-1] += reward
            if done:
                obs = env.reset()
    # Compute mean reward for the last 100 episodes
    mean_100ep_reward = round(np.mean(episode_rewards), 1)
    print("Mean reward:", mean_100ep_reward, "Num episodes:", len(episode_rewards))
    return mean_100ep_reward

# %%
def make_env(env_id, rank, seed=0):
    """
    Utility function for multiprocessed env.

    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environments you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    """
    def _init():
        env = gym.make(env_id)
        env.seed(seed + rank)
        return env
    set_global_seeds(seed)
    return _init


# Stable Baselines provides you with make_vec_env() helper
# which does exactly the previous steps for you:
# env = make_vec_env(env_id, n_envs=num_cpu, seed=0)

# %%
env_id = "BipedalWalker-v2"
num_cpu = 8  # Number of processes to use
env = SubprocVecEnv([make_env(env_id, i) for i in range(num_cpu)])

# %%
# %%time
model = ACKTR(MlpLstmPolicy, env, verbose=1)
model.learn(total_timesteps=500000, log_interval=10)
# Out:
# ---------------------------------
# | explained_variance | 0.00325  |
# | fps                | 113      |
# | nupdates           | 1        |
# | policy_entropy     | 5.68     |
# | policy_loss        | -0.115   |
# | total_timesteps    | 0        |
# | value_loss         | 3.3      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00784 |
# | fps                | 389      |
# | nupdates           | 10       |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.115   |
# | total_timesteps    | 1449     |
# | value_loss         | 2.28     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0663   |
# | fps                | 165      |
# | nupdates           | 20       |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0227  |
# | total_timesteps    | 3059     |
# | value_loss         | 0.765    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.202    |
# | fps                | 139      |
# | nupdates           | 30       |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.0374  |
# | total_timesteps    | 4669     |
# | value_loss         | 1.18     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.511   |
# | fps                | 121      |
# | nupdates           | 40       |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.111    |
# | total_timesteps    | 6279     |
# | value_loss         | 0.435    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0344   |
# | fps                | 115      |
# | nupdates           | 50       |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0871  |
# | total_timesteps    | 7889     |
# | value_loss         | 680      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0461  |
# | fps                | 111      |
# | nupdates           | 60       |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.00124 |
# | total_timesteps    | 9499     |
# | value_loss         | 0.154    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.184    |
# | fps                | 108      |
# | nupdates           | 70       |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0646  |
# | total_timesteps    | 11109    |
# | value_loss         | 0.17     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0497   |
# | fps                | 105      |
# | nupdates           | 80       |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.0196  |
# | total_timesteps    | 12719    |
# | value_loss         | 3.73     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00889  |
# | fps                | 104      |
# | nupdates           | 90       |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.0931   |
# | total_timesteps    | 14329    |
# | value_loss         | 256      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0378   |
# | fps                | 103      |
# | nupdates           | 100      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.203   |
# | total_timesteps    | 15939    |
# | value_loss         | 297      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0562   |
# | fps                | 101      |
# | nupdates           | 110      |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.0219   |
# | total_timesteps    | 17549    |
# | value_loss         | 432      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.909    |
# | fps                | 101      |
# | nupdates           | 120      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.146   |
# | total_timesteps    | 19159    |
# | value_loss         | 0.899    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.969    |
# | fps                | 100      |
# | nupdates           | 130      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.0262  |
# | total_timesteps    | 20769    |
# | value_loss         | 0.721    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.167    |
# | fps                | 100      |
# | nupdates           | 140      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.0017  |
# | total_timesteps    | 22379    |
# | value_loss         | 952      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.88     |
# | fps                | 100      |
# | nupdates           | 150      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0376  |
# | total_timesteps    | 23989    |
# | value_loss         | 2.98     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.192    |
# | fps                | 100      |
# | nupdates           | 160      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.172   |
# | total_timesteps    | 25599    |
# | value_loss         | 0.12     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.8     |
# | fps                | 100      |
# | nupdates           | 170      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.206   |
# | total_timesteps    | 27209    |
# | value_loss         | 3.92     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.292   |
# | fps                | 100      |
# | nupdates           | 180      |
# | policy_entropy     | 5.89     |
# | policy_loss        | -0.0617  |
# | total_timesteps    | 28819    |
# | value_loss         | 0.0848   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.448    |
# | fps                | 100      |
# | nupdates           | 190      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.114   |
# | total_timesteps    | 30429    |
# | value_loss         | 0.156    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.682    |
# | fps                | 100      |
# | nupdates           | 200      |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.0179   |
# | total_timesteps    | 32039    |
# | value_loss         | 0.26     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.764    |
# | fps                | 101      |
# | nupdates           | 210      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.248   |
# | total_timesteps    | 33649    |
# | value_loss         | 2.39     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.415    |
# | fps                | 100      |
# | nupdates           | 220      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0406  |
# | total_timesteps    | 35259    |
# | value_loss         | 12.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.746    |
# | fps                | 100      |
# | nupdates           | 230      |
# | policy_entropy     | 5.91     |
# | policy_loss        | 0.103    |
# | total_timesteps    | 36869    |
# | value_loss         | 1.43     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.223    |
# | fps                | 100      |
# | nupdates           | 240      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0758  |
# | total_timesteps    | 38479    |
# | value_loss         | 516      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.922    |
# | fps                | 100      |
# | nupdates           | 250      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0294  |
# | total_timesteps    | 40089    |
# | value_loss         | 1.68     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.8      |
# | fps                | 100      |
# | nupdates           | 260      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.27    |
# | total_timesteps    | 41699    |
# | value_loss         | 6.47     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.00743 |
# | fps                | 100      |
# | nupdates           | 270      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.026   |
# | total_timesteps    | 43309    |
# | value_loss         | 0.522    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.173    |
# | fps                | 100      |
# | nupdates           | 280      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0563  |
# | total_timesteps    | 44919    |
# | value_loss         | 0.0736   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.413    |
# | fps                | 100      |
# | nupdates           | 290      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.142   |
# | total_timesteps    | 46529    |
# | value_loss         | 0.191    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.034    |
# | fps                | 100      |
# | nupdates           | 300      |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.012    |
# | total_timesteps    | 48139    |
# | value_loss         | 0.225    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0141  |
# | fps                | 101      |
# | nupdates           | 310      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.0926  |
# | total_timesteps    | 49749    |
# | value_loss         | 0.145    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.502    |
# | fps                | 101      |
# | nupdates           | 320      |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.0467   |
# | total_timesteps    | 51359    |
# | value_loss         | 1.54     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.89     |
# | fps                | 101      |
# | nupdates           | 330      |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.00979  |
# | total_timesteps    | 52969    |
# | value_loss         | 0.542    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.865    |
# | fps                | 101      |
# | nupdates           | 340      |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.0529   |
# | total_timesteps    | 54579    |
# | value_loss         | 0.0771   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.547    |
# | fps                | 101      |
# | nupdates           | 350      |
# | policy_entropy     | 5.91     |
# | policy_loss        | 0.0243   |
# | total_timesteps    | 56189    |
# | value_loss         | 0.151    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.134    |
# | fps                | 101      |
# | nupdates           | 360      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.178   |
# | total_timesteps    | 57799    |
# | value_loss         | 0.121    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.474    |
# | fps                | 101      |
# | nupdates           | 370      |
# | policy_entropy     | 5.91     |
# | policy_loss        | 0.038    |
# | total_timesteps    | 59409    |
# | value_loss         | 0.0884   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.979    |
# | fps                | 101      |
# | nupdates           | 380      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.305   |
# | total_timesteps    | 61019    |
# | value_loss         | 2.23     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.357    |
# | fps                | 101      |
# | nupdates           | 390      |
# | policy_entropy     | 5.91     |
# | policy_loss        | 0.0527   |
# | total_timesteps    | 62629    |
# | value_loss         | 459      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.384    |
# | fps                | 101      |
# | nupdates           | 400      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.02    |
# | total_timesteps    | 64239    |
# | value_loss         | 1.29e+03 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.416    |
# | fps                | 101      |
# | nupdates           | 410      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0853  |
# | total_timesteps    | 65849    |
# | value_loss         | 94.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.419    |
# | fps                | 101      |
# | nupdates           | 420      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0132  |
# | total_timesteps    | 67459    |
# | value_loss         | 297      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.206    |
# | fps                | 102      |
# | nupdates           | 430      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.17    |
# | total_timesteps    | 69069    |
# | value_loss         | 1.5e+03  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.496    |
# | fps                | 102      |
# | nupdates           | 440      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0421  |
# | total_timesteps    | 70679    |
# | value_loss         | 363      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.802    |
# | fps                | 102      |
# | nupdates           | 450      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0141  |
# | total_timesteps    | 72289    |
# | value_loss         | 12.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.578    |
# | fps                | 102      |
# | nupdates           | 460      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0616  |
# | total_timesteps    | 73899    |
# | value_loss         | 48.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.896    |
# | fps                | 102      |
# | nupdates           | 470      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0403  |
# | total_timesteps    | 75509    |
# | value_loss         | 7.72     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.6      |
# | fps                | 102      |
# | nupdates           | 480      |
# | policy_entropy     | 5.91     |
# | policy_loss        | 0.0197   |
# | total_timesteps    | 77119    |
# | value_loss         | 141      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.485    |
# | fps                | 102      |
# | nupdates           | 490      |
# | policy_entropy     | 5.91     |
# | policy_loss        | 0.0522   |
# | total_timesteps    | 78729    |
# | value_loss         | 255      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.688    |
# | fps                | 102      |
# | nupdates           | 500      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.156   |
# | total_timesteps    | 80339    |
# | value_loss         | 20.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.488    |
# | fps                | 102      |
# | nupdates           | 510      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.165   |
# | total_timesteps    | 81949    |
# | value_loss         | 388      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.963    |
# | fps                | 102      |
# | nupdates           | 520      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.0209  |
# | total_timesteps    | 83559    |
# | value_loss         | 1.11     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.852    |
# | fps                | 102      |
# | nupdates           | 530      |
# | policy_entropy     | 5.91     |
# | policy_loss        | 0.0887   |
# | total_timesteps    | 85169    |
# | value_loss         | 0.849    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.18    |
# | fps                | 102      |
# | nupdates           | 540      |
# | policy_entropy     | 5.91     |
# | policy_loss        | 0.0242   |
# | total_timesteps    | 86779    |
# | value_loss         | 0.931    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.571    |
# | fps                | 102      |
# | nupdates           | 550      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.311   |
# | total_timesteps    | 88389    |
# | value_loss         | 0.0851   |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.32     |
# | fps                | 102      |
# | nupdates           | 560      |
# | policy_entropy     | 5.91     |
# | policy_loss        | -0.173   |
# | total_timesteps    | 89999    |
# | value_loss         | 0.153    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.467    |
# | fps                | 102      |
# | nupdates           | 570      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.121   |
# | total_timesteps    | 91609    |
# | value_loss         | 0.438    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.632    |
# | fps                | 102      |
# | nupdates           | 580      |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.0338   |
# | total_timesteps    | 93219    |
# | value_loss         | 0.132    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.573    |
# | fps                | 102      |
# | nupdates           | 590      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.129   |
# | total_timesteps    | 94829    |
# | value_loss         | 0.156    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.762    |
# | fps                | 102      |
# | nupdates           | 600      |
# | policy_entropy     | 5.91     |
# | policy_loss        | 0.126    |
# | total_timesteps    | 96439    |
# | value_loss         | 0.0602   |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.072   |
# | fps                | 102      |
# | nupdates           | 610      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.13    |
# | total_timesteps    | 98049    |
# | value_loss         | 0.169    |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0507  |
# | fps                | 102      |
# | nupdates           | 620      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.113   |
# | total_timesteps    | 99659    |
# | value_loss         | 0.828    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.202    |
# | fps                | 102      |
# | nupdates           | 630      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.22    |
# | total_timesteps    | 101269   |
# | value_loss         | 0.148    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.951    |
# | fps                | 102      |
# | nupdates           | 640      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.0273  |
# | total_timesteps    | 102879   |
# | value_loss         | 4.34     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.847    |
# | fps                | 102      |
# | nupdates           | 650      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.208   |
# | total_timesteps    | 104489   |
# | value_loss         | 0.67     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.343    |
# | fps                | 102      |
# | nupdates           | 660      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.0333  |
# | total_timesteps    | 106099   |
# | value_loss         | 0.24     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 102      |
# | nupdates           | 670      |
# | policy_entropy     | 5.9      |
# | policy_loss        | 0.0789   |
# | total_timesteps    | 107709   |
# | value_loss         | 1.47     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.0532  |
# | fps                | 102      |
# | nupdates           | 680      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.0368  |
# | total_timesteps    | 109319   |
# | value_loss         | 0.427    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.637    |
# | fps                | 102      |
# | nupdates           | 690      |
# | policy_entropy     | 5.9      |
# | policy_loss        | -0.00717 |
# | total_timesteps    | 110929   |
# | value_loss         | 284      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.16     |
# | fps                | 103      |
# | nupdates           | 700      |
# | policy_entropy     | 5.89     |
# | policy_loss        | 0.0791   |
# | total_timesteps    | 112539   |
# | value_loss         | 0.272    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.433    |
# | fps                | 103      |
# | nupdates           | 710      |
# | policy_entropy     | 5.89     |
# | policy_loss        | -0.0593  |
# | total_timesteps    | 114149   |
# | value_loss         | 0.479    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.685    |
# | fps                | 103      |
# | nupdates           | 720      |
# | policy_entropy     | 5.89     |
# | policy_loss        | -0.281   |
# | total_timesteps    | 115759   |
# | value_loss         | 0.403    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.665    |
# | fps                | 103      |
# | nupdates           | 730      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.0594  |
# | total_timesteps    | 117369   |
# | value_loss         | 251      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.254    |
# | fps                | 103      |
# | nupdates           | 740      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.0738  |
# | total_timesteps    | 118979   |
# | value_loss         | 0.601    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.92     |
# | fps                | 103      |
# | nupdates           | 750      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.265   |
# | total_timesteps    | 120589   |
# | value_loss         | 2.9      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.994    |
# | fps                | 103      |
# | nupdates           | 760      |
# | policy_entropy     | 5.88     |
# | policy_loss        | 0.0976   |
# | total_timesteps    | 122199   |
# | value_loss         | 1.1      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.791    |
# | fps                | 104      |
# | nupdates           | 770      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.162   |
# | total_timesteps    | 123809   |
# | value_loss         | 3.08     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.385    |
# | fps                | 104      |
# | nupdates           | 780      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.0248  |
# | total_timesteps    | 125419   |
# | value_loss         | 0.742    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.933    |
# | fps                | 104      |
# | nupdates           | 790      |
# | policy_entropy     | 5.88     |
# | policy_loss        | 0.0922   |
# | total_timesteps    | 127029   |
# | value_loss         | 2.3      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.516    |
# | fps                | 104      |
# | nupdates           | 800      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.0816  |
# | total_timesteps    | 128639   |
# | value_loss         | 0.741    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.982    |
# | fps                | 104      |
# | nupdates           | 810      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.246   |
# | total_timesteps    | 130249   |
# | value_loss         | 2.94     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.894    |
# | fps                | 104      |
# | nupdates           | 820      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.051   |
# | total_timesteps    | 131859   |
# | value_loss         | 1.21     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.598    |
# | fps                | 104      |
# | nupdates           | 830      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.218   |
# | total_timesteps    | 133469   |
# | value_loss         | 0.626    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0685   |
# | fps                | 104      |
# | nupdates           | 840      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.114   |
# | total_timesteps    | 135079   |
# | value_loss         | 0.641    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.396    |
# | fps                | 104      |
# | nupdates           | 850      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.139   |
# | total_timesteps    | 136689   |
# | value_loss         | 1.85     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0293   |
# | fps                | 104      |
# | nupdates           | 860      |
# | policy_entropy     | 5.87     |
# | policy_loss        | 0.066    |
# | total_timesteps    | 138299   |
# | value_loss         | 0.717    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.596    |
# | fps                | 104      |
# | nupdates           | 870      |
# | policy_entropy     | 5.87     |
# | policy_loss        | 0.062    |
# | total_timesteps    | 139909   |
# | value_loss         | 242      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.434    |
# | fps                | 105      |
# | nupdates           | 880      |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.13    |
# | total_timesteps    | 141519   |
# | value_loss         | 93.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 105      |
# | nupdates           | 890      |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.0309  |
# | total_timesteps    | 143129   |
# | value_loss         | 1.68     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.395    |
# | fps                | 105      |
# | nupdates           | 900      |
# | policy_entropy     | 5.88     |
# | policy_loss        | 0.0172   |
# | total_timesteps    | 144739   |
# | value_loss         | 0.599    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.715    |
# | fps                | 105      |
# | nupdates           | 910      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.0865  |
# | total_timesteps    | 146349   |
# | value_loss         | 30.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.856    |
# | fps                | 105      |
# | nupdates           | 920      |
# | policy_entropy     | 5.88     |
# | policy_loss        | 0.248    |
# | total_timesteps    | 147959   |
# | value_loss         | 60       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.58     |
# | fps                | 105      |
# | nupdates           | 930      |
# | policy_entropy     | 5.87     |
# | policy_loss        | 0.0145   |
# | total_timesteps    | 149569   |
# | value_loss         | 1.17     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.539    |
# | fps                | 105      |
# | nupdates           | 940      |
# | policy_entropy     | 5.87     |
# | policy_loss        | 0.0309   |
# | total_timesteps    | 151179   |
# | value_loss         | 0.46     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.697    |
# | fps                | 105      |
# | nupdates           | 950      |
# | policy_entropy     | 5.87     |
# | policy_loss        | 0.0966   |
# | total_timesteps    | 152789   |
# | value_loss         | 0.451    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.674    |
# | fps                | 105      |
# | nupdates           | 960      |
# | policy_entropy     | 5.87     |
# | policy_loss        | 0.00776  |
# | total_timesteps    | 154399   |
# | value_loss         | 0.867    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 105      |
# | nupdates           | 970      |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.169   |
# | total_timesteps    | 156009   |
# | value_loss         | 1.38     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.377    |
# | fps                | 105      |
# | nupdates           | 980      |
# | policy_entropy     | 5.88     |
# | policy_loss        | -0.24    |
# | total_timesteps    | 157619   |
# | value_loss         | 1.54     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.983    |
# | fps                | 105      |
# | nupdates           | 990      |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.0469  |
# | total_timesteps    | 159229   |
# | value_loss         | 3.32     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.735    |
# | fps                | 105      |
# | nupdates           | 1000     |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.0869  |
# | total_timesteps    | 160839   |
# | value_loss         | 0.652    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.984    |
# | fps                | 106      |
# | nupdates           | 1010     |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.0673  |
# | total_timesteps    | 162449   |
# | value_loss         | 3.05     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.497    |
# | fps                | 106      |
# | nupdates           | 1020     |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.165   |
# | total_timesteps    | 164059   |
# | value_loss         | 0.693    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.715    |
# | fps                | 106      |
# | nupdates           | 1030     |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.187   |
# | total_timesteps    | 165669   |
# | value_loss         | 0.749    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.66     |
# | fps                | 106      |
# | nupdates           | 1040     |
# | policy_entropy     | 5.86     |
# | policy_loss        | 0.0916   |
# | total_timesteps    | 167279   |
# | value_loss         | 0.245    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.631    |
# | fps                | 106      |
# | nupdates           | 1050     |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.0614  |
# | total_timesteps    | 168889   |
# | value_loss         | 0.696    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.661    |
# | fps                | 106      |
# | nupdates           | 1060     |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.312   |
# | total_timesteps    | 170499   |
# | value_loss         | 0.875    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.716    |
# | fps                | 106      |
# | nupdates           | 1070     |
# | policy_entropy     | 5.87     |
# | policy_loss        | -0.00798 |
# | total_timesteps    | 172109   |
# | value_loss         | 83.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.662    |
# | fps                | 106      |
# | nupdates           | 1080     |
# | policy_entropy     | 5.86     |
# | policy_loss        | -0.177   |
# | total_timesteps    | 173719   |
# | value_loss         | 0.445    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.98     |
# | fps                | 105      |
# | nupdates           | 1090     |
# | policy_entropy     | 5.86     |
# | policy_loss        | -0.0759  |
# | total_timesteps    | 175329   |
# | value_loss         | 1.45     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.681    |
# | fps                | 105      |
# | nupdates           | 1100     |
# | policy_entropy     | 5.86     |
# | policy_loss        | -0.216   |
# | total_timesteps    | 176939   |
# | value_loss         | 365      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.483    |
# | fps                | 105      |
# | nupdates           | 1110     |
# | policy_entropy     | 5.86     |
# | policy_loss        | 0.0576   |
# | total_timesteps    | 178549   |
# | value_loss         | 0.773    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.503    |
# | fps                | 105      |
# | nupdates           | 1120     |
# | policy_entropy     | 5.86     |
# | policy_loss        | -0.193   |
# | total_timesteps    | 180159   |
# | value_loss         | 7.72     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.917    |
# | fps                | 105      |
# | nupdates           | 1130     |
# | policy_entropy     | 5.86     |
# | policy_loss        | -0.15    |
# | total_timesteps    | 181769   |
# | value_loss         | 0.352    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.948    |
# | fps                | 105      |
# | nupdates           | 1140     |
# | policy_entropy     | 5.86     |
# | policy_loss        | -0.129   |
# | total_timesteps    | 183379   |
# | value_loss         | 0.42     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.699    |
# | fps                | 104      |
# | nupdates           | 1150     |
# | policy_entropy     | 5.86     |
# | policy_loss        | -0.29    |
# | total_timesteps    | 184989   |
# | value_loss         | 57.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.801    |
# | fps                | 104      |
# | nupdates           | 1160     |
# | policy_entropy     | 5.86     |
# | policy_loss        | -0.306   |
# | total_timesteps    | 186599   |
# | value_loss         | 0.514    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.716    |
# | fps                | 104      |
# | nupdates           | 1170     |
# | policy_entropy     | 5.85     |
# | policy_loss        | -0.179   |
# | total_timesteps    | 188209   |
# | value_loss         | 0.348    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.781    |
# | fps                | 104      |
# | nupdates           | 1180     |
# | policy_entropy     | 5.85     |
# | policy_loss        | -0.0138  |
# | total_timesteps    | 189819   |
# | value_loss         | 0.228    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.214    |
# | fps                | 104      |
# | nupdates           | 1190     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.0345  |
# | total_timesteps    | 191429   |
# | value_loss         | 5.52     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.792    |
# | fps                | 104      |
# | nupdates           | 1200     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.111   |
# | total_timesteps    | 193039   |
# | value_loss         | 1.47     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.866    |
# | fps                | 104      |
# | nupdates           | 1210     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.0792  |
# | total_timesteps    | 194649   |
# | value_loss         | 0.952    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.359    |
# | fps                | 104      |
# | nupdates           | 1220     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.106   |
# | total_timesteps    | 196259   |
# | value_loss         | 94       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 104      |
# | nupdates           | 1230     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.0398  |
# | total_timesteps    | 197869   |
# | value_loss         | 0.302    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.788    |
# | fps                | 104      |
# | nupdates           | 1240     |
# | policy_entropy     | 5.84     |
# | policy_loss        | 0.035    |
# | total_timesteps    | 199479   |
# | value_loss         | 0.337    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.843    |
# | fps                | 104      |
# | nupdates           | 1250     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.288   |
# | total_timesteps    | 201089   |
# | value_loss         | 0.255    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.397    |
# | fps                | 104      |
# | nupdates           | 1260     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.0139  |
# | total_timesteps    | 202699   |
# | value_loss         | 1.06     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.887    |
# | fps                | 104      |
# | nupdates           | 1270     |
# | policy_entropy     | 5.84     |
# | policy_loss        | 0.0298   |
# | total_timesteps    | 204309   |
# | value_loss         | 25       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.922    |
# | fps                | 104      |
# | nupdates           | 1280     |
# | policy_entropy     | 5.84     |
# | policy_loss        | 0.0551   |
# | total_timesteps    | 205919   |
# | value_loss         | 16.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.491    |
# | fps                | 104      |
# | nupdates           | 1290     |
# | policy_entropy     | 5.84     |
# | policy_loss        | 0.0876   |
# | total_timesteps    | 207529   |
# | value_loss         | 0.378    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.563    |
# | fps                | 104      |
# | nupdates           | 1300     |
# | policy_entropy     | 5.84     |
# | policy_loss        | 0.101    |
# | total_timesteps    | 209139   |
# | value_loss         | 44.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.735    |
# | fps                | 104      |
# | nupdates           | 1310     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.0299  |
# | total_timesteps    | 210749   |
# | value_loss         | 0.453    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.995    |
# | fps                | 104      |
# | nupdates           | 1320     |
# | policy_entropy     | 5.84     |
# | policy_loss        | 0.0356   |
# | total_timesteps    | 212359   |
# | value_loss         | 1.64     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.842    |
# | fps                | 104      |
# | nupdates           | 1330     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.0489  |
# | total_timesteps    | 213969   |
# | value_loss         | 22.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.535    |
# | fps                | 104      |
# | nupdates           | 1340     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.0317  |
# | total_timesteps    | 215579   |
# | value_loss         | 3.13     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 104      |
# | nupdates           | 1350     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.162   |
# | total_timesteps    | 217189   |
# | value_loss         | 3.1      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.795    |
# | fps                | 104      |
# | nupdates           | 1360     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.151   |
# | total_timesteps    | 218799   |
# | value_loss         | 0.584    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.568    |
# | fps                | 104      |
# | nupdates           | 1370     |
# | policy_entropy     | 5.84     |
# | policy_loss        | -0.0527  |
# | total_timesteps    | 220409   |
# | value_loss         | 0.365    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.772    |
# | fps                | 104      |
# | nupdates           | 1380     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.168   |
# | total_timesteps    | 222019   |
# | value_loss         | 0.247    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.588    |
# | fps                | 104      |
# | nupdates           | 1390     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.183   |
# | total_timesteps    | 223629   |
# | value_loss         | 1.15     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.998    |
# | fps                | 104      |
# | nupdates           | 1400     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.146   |
# | total_timesteps    | 225239   |
# | value_loss         | 0.476    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.455    |
# | fps                | 104      |
# | nupdates           | 1410     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.116   |
# | total_timesteps    | 226849   |
# | value_loss         | 1.59     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.991    |
# | fps                | 104      |
# | nupdates           | 1420     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.135   |
# | total_timesteps    | 228459   |
# | value_loss         | 2.98     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.889    |
# | fps                | 104      |
# | nupdates           | 1430     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.0284  |
# | total_timesteps    | 230069   |
# | value_loss         | 51.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.739    |
# | fps                | 104      |
# | nupdates           | 1440     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.121   |
# | total_timesteps    | 231679   |
# | value_loss         | 85.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.723    |
# | fps                | 104      |
# | nupdates           | 1450     |
# | policy_entropy     | 5.83     |
# | policy_loss        | 0.142    |
# | total_timesteps    | 233289   |
# | value_loss         | 284      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.481    |
# | fps                | 104      |
# | nupdates           | 1460     |
# | policy_entropy     | 5.83     |
# | policy_loss        | 0.0125   |
# | total_timesteps    | 234899   |
# | value_loss         | 690      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.891    |
# | fps                | 104      |
# | nupdates           | 1470     |
# | policy_entropy     | 5.83     |
# | policy_loss        | 0.0542   |
# | total_timesteps    | 236509   |
# | value_loss         | 37       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.691    |
# | fps                | 104      |
# | nupdates           | 1480     |
# | policy_entropy     | 5.83     |
# | policy_loss        | 0.0429   |
# | total_timesteps    | 238119   |
# | value_loss         | 50       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.0527   |
# | fps                | 104      |
# | nupdates           | 1490     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.388   |
# | total_timesteps    | 239729   |
# | value_loss         | 69.5     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.782    |
# | fps                | 104      |
# | nupdates           | 1500     |
# | policy_entropy     | 5.83     |
# | policy_loss        | 0.037    |
# | total_timesteps    | 241339   |
# | value_loss         | 19       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.527    |
# | fps                | 104      |
# | nupdates           | 1510     |
# | policy_entropy     | 5.83     |
# | policy_loss        | 0.0722   |
# | total_timesteps    | 242949   |
# | value_loss         | 72.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.609    |
# | fps                | 104      |
# | nupdates           | 1520     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.164   |
# | total_timesteps    | 244559   |
# | value_loss         | 203      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.768    |
# | fps                | 104      |
# | nupdates           | 1530     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.178   |
# | total_timesteps    | 246169   |
# | value_loss         | 8.2      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.757    |
# | fps                | 104      |
# | nupdates           | 1540     |
# | policy_entropy     | 5.83     |
# | policy_loss        | 0.0361   |
# | total_timesteps    | 247779   |
# | value_loss         | 187      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -1.22    |
# | fps                | 104      |
# | nupdates           | 1550     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.205   |
# | total_timesteps    | 249389   |
# | value_loss         | 17.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.672    |
# | fps                | 104      |
# | nupdates           | 1560     |
# | policy_entropy     | 5.83     |
# | policy_loss        | -0.311   |
# | total_timesteps    | 250999   |
# ...
# ---------------------------------
# | explained_variance | 0.176    |
# | fps                | 100      |
# | nupdates           | 2610     |
# | policy_entropy     | 5.73     |
# | policy_loss        | 0.134    |
# | total_timesteps    | 420049   |
# | value_loss         | 42.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.902    |
# | fps                | 100      |
# | nupdates           | 2620     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0799  |
# | total_timesteps    | 421659   |
# | value_loss         | 0.817    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.656    |
# | fps                | 100      |
# | nupdates           | 2630     |
# | policy_entropy     | 5.72     |
# | policy_loss        | 0.1      |
# | total_timesteps    | 423269   |
# | value_loss         | 199      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.953    |
# | fps                | 100      |
# | nupdates           | 2640     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0741  |
# | total_timesteps    | 424879   |
# | value_loss         | 0.501    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.827    |
# | fps                | 100      |
# | nupdates           | 2650     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0727  |
# | total_timesteps    | 426489   |
# | value_loss         | 256      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.909    |
# | fps                | 100      |
# | nupdates           | 2660     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0841  |
# | total_timesteps    | 428099   |
# | value_loss         | 78.8     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.902    |
# | fps                | 100      |
# | nupdates           | 2670     |
# | policy_entropy     | 5.73     |
# | policy_loss        | -0.0909  |
# | total_timesteps    | 429709   |
# | value_loss         | 32.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.543   |
# | fps                | 100      |
# | nupdates           | 2680     |
# | policy_entropy     | 5.73     |
# | policy_loss        | -0.166   |
# | total_timesteps    | 431319   |
# | value_loss         | 15       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.358    |
# | fps                | 100      |
# | nupdates           | 2690     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0701  |
# | total_timesteps    | 432929   |
# | value_loss         | 2.16     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.842    |
# | fps                | 99       |
# | nupdates           | 2700     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0233  |
# | total_timesteps    | 434539   |
# | value_loss         | 100      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.996    |
# | fps                | 99       |
# | nupdates           | 2710     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.176   |
# | total_timesteps    | 436149   |
# | value_loss         | 3.71     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.96     |
# | fps                | 99       |
# | nupdates           | 2720     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0443  |
# | total_timesteps    | 437759   |
# | value_loss         | 27.7     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.645    |
# | fps                | 99       |
# | nupdates           | 2730     |
# | policy_entropy     | 5.72     |
# | policy_loss        | 0.0622   |
# | total_timesteps    | 439369   |
# | value_loss         | 125      |
# ---------------------------------
# ---------------------------------
# | explained_variance | -4.13    |
# | fps                | 99       |
# | nupdates           | 2740     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.208   |
# | total_timesteps    | 440979   |
# | value_loss         | 3.33     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.776    |
# | fps                | 99       |
# | nupdates           | 2750     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.00455 |
# | total_timesteps    | 442589   |
# | value_loss         | 281      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.948    |
# | fps                | 99       |
# | nupdates           | 2760     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0925  |
# | total_timesteps    | 444199   |
# | value_loss         | 14.6     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.841    |
# | fps                | 99       |
# | nupdates           | 2770     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.209   |
# | total_timesteps    | 445809   |
# | value_loss         | 304      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.773    |
# | fps                | 99       |
# | nupdates           | 2780     |
# | policy_entropy     | 5.72     |
# | policy_loss        | 0.0292   |
# | total_timesteps    | 447419   |
# | value_loss         | 46.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.978    |
# | fps                | 98       |
# | nupdates           | 2790     |
# | policy_entropy     | 5.71     |
# | policy_loss        | -0.366   |
# | total_timesteps    | 449029   |
# | value_loss         | 12.3     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.987    |
# | fps                | 98       |
# | nupdates           | 2800     |
# | policy_entropy     | 5.71     |
# | policy_loss        | 0.0181   |
# | total_timesteps    | 450639   |
# | value_loss         | 5.92     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.992    |
# | fps                | 98       |
# | nupdates           | 2810     |
# | policy_entropy     | 5.71     |
# | policy_loss        | -0.00694 |
# | total_timesteps    | 452249   |
# | value_loss         | 3.62     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.774    |
# | fps                | 98       |
# | nupdates           | 2820     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.152   |
# | total_timesteps    | 453859   |
# | value_loss         | 1.35     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.806    |
# | fps                | 98       |
# | nupdates           | 2830     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.097   |
# | total_timesteps    | 455469   |
# | value_loss         | 358      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.885    |
# | fps                | 98       |
# | nupdates           | 2840     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0554  |
# | total_timesteps    | 457079   |
# | value_loss         | 159      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.848    |
# | fps                | 98       |
# | nupdates           | 2850     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.232   |
# | total_timesteps    | 458689   |
# | value_loss         | 69.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.807    |
# | fps                | 98       |
# | nupdates           | 2860     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.162   |
# | total_timesteps    | 460299   |
# | value_loss         | 69.2     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.961    |
# | fps                | 98       |
# | nupdates           | 2870     |
# | policy_entropy     | 5.72     |
# | policy_loss        | 0.122    |
# | total_timesteps    | 461909   |
# | value_loss         | 0.904    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.761    |
# | fps                | 98       |
# | nupdates           | 2880     |
# | policy_entropy     | 5.72     |
# | policy_loss        | 0.155    |
# | total_timesteps    | 463519   |
# | value_loss         | 69.9     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.409    |
# | fps                | 98       |
# | nupdates           | 2890     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.241   |
# | total_timesteps    | 465129   |
# | value_loss         | 25.4     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.446    |
# | fps                | 98       |
# | nupdates           | 2900     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0754  |
# | total_timesteps    | 466739   |
# | value_loss         | 0.876    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.993    |
# | fps                | 98       |
# | nupdates           | 2910     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0865  |
# | total_timesteps    | 468349   |
# | value_loss         | 3.02     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.484    |
# | fps                | 98       |
# | nupdates           | 2920     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.109   |
# | total_timesteps    | 469959   |
# | value_loss         | 1.71     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.507    |
# | fps                | 97       |
# | nupdates           | 2930     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.174   |
# | total_timesteps    | 471569   |
# | value_loss         | 0.721    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.888    |
# | fps                | 97       |
# | nupdates           | 2940     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0249  |
# | total_timesteps    | 473179   |
# | value_loss         | 107      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.244    |
# | fps                | 97       |
# | nupdates           | 2950     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0304  |
# | total_timesteps    | 474789   |
# | value_loss         | 189      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.32     |
# | fps                | 97       |
# | nupdates           | 2960     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0244  |
# | total_timesteps    | 476399   |
# | value_loss         | 232      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.335    |
# | fps                | 97       |
# | nupdates           | 2970     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.15    |
# | total_timesteps    | 478009   |
# | value_loss         | 265      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.717    |
# | fps                | 97       |
# | nupdates           | 2980     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.135   |
# | total_timesteps    | 479619   |
# | value_loss         | 91       |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.293    |
# | fps                | 97       |
# | nupdates           | 2990     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.181   |
# | total_timesteps    | 481229   |
# | value_loss         | 208      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.918    |
# | fps                | 97       |
# | nupdates           | 3000     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.148   |
# | total_timesteps    | 482839   |
# | value_loss         | 64.1     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.593    |
# | fps                | 97       |
# | nupdates           | 3010     |
# | policy_entropy     | 5.72     |
# | policy_loss        | 0.035    |
# | total_timesteps    | 484449   |
# | value_loss         | 0.626    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.891    |
# | fps                | 97       |
# | nupdates           | 3020     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0172  |
# | total_timesteps    | 486059   |
# | value_loss         | 1.45     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.86     |
# | fps                | 97       |
# | nupdates           | 3030     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.204   |
# | total_timesteps    | 487669   |
# | value_loss         | 1.23     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.917   |
# | fps                | 97       |
# | nupdates           | 3040     |
# | policy_entropy     | 5.72     |
# | policy_loss        | 0.00974  |
# | total_timesteps    | 489279   |
# | value_loss         | 7.6      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.127    |
# | fps                | 97       |
# | nupdates           | 3050     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.192   |
# | total_timesteps    | 490889   |
# | value_loss         | 119      |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.914    |
# | fps                | 97       |
# | nupdates           | 3060     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.111   |
# | total_timesteps    | 492499   |
# | value_loss         | 1.62     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.737    |
# | fps                | 97       |
# | nupdates           | 3070     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0428  |
# | total_timesteps    | 494109   |
# | value_loss         | 0.53     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.999    |
# | fps                | 97       |
# | nupdates           | 3080     |
# | policy_entropy     | 5.71     |
# | policy_loss        | -0.0364  |
# | total_timesteps    | 495719   |
# | value_loss         | 0.465    |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.985    |
# | fps                | 97       |
# | nupdates           | 3090     |
# | policy_entropy     | 5.71     |
# | policy_loss        | -0.191   |
# | total_timesteps    | 497329   |
# | value_loss         | 7.58     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.817    |
# | fps                | 97       |
# | nupdates           | 3100     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0626  |
# | total_timesteps    | 498939   |
# | value_loss         | 0.46     |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.135   |
# | fps                | 96       |
# | nupdates           | 3110     |
# | policy_entropy     | 5.72     |
# | policy_loss        | 0.0213   |
# | total_timesteps    | 500549   |
# | value_loss         | 1.18     |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.313    |
# | fps                | 96       |
# | nupdates           | 3120     |
# | policy_entropy     | 5.72     |
# | policy_loss        | -0.0784  |
# | total_timesteps    | 502159   |
# | value_loss         | 28.2     |
# ---------------------------------
# CPU times: user 1h 23min 13s, sys: 32.2 s, total: 1h 23min 45s
# Wall time: 1h 26min 2s

# %%
model.save("acktr_lstm_parallel_500k")

# %%
env = gym.make('BipedalWalker-v2')
env = SubprocVecEnv([make_env(env_id, i) for i in range(num_cpu)])
model = ACKTR.load("acktr_lstm_parallel_500k", env=env, nminibatches=16)

# %%
num_episodes = 100

# %%
episode_rewards = []
obs = env.reset()
for i in range(num_episodes):
    episode_rewards.append(0.0)
    done = False
    while not done:
        # _states are only useful when using LSTM policies
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        reward, done, info = reward[0], done[0], info[0]
        # Stats
        episode_rewards[-1] += reward
        if done:
            obs = env.reset()
    # Compute mean reward for the last 100 epis

# %%
np.mean(episode_rewards)
# Out:
# 24.363377715390143

# %%
evaluate_2(model, 10)[0]

# %%
def evaluate_2(model, num_episodes=100):
    """
    Evaluate a RL agent
    :param model: (BaseRLModel object) the RL Agent
    :param num_episodes: (int) number of episodes
    :return: (float) Mean reward for the given number of episodes
    """
    episode_rewards = []
    obs = env.reset()
    for i in range(num_episodes):
        episode_rewards.append(0.0)
        done = False
        while not done:
            # _states are only useful when using LSTM policies
            action, _states = model.predict(obs)
            obs, reward, done, info = env.step(action)
            reward, done, info = reward[0], done[0], info[0]
            # Stats
            episode_rewards[-1] += reward
            if done:
                obs = env.reset()
    # Compute mean reward for the last 100 episodes
    mean_100ep_reward = round(np.mean(episode_rewards), 1)
    print("Mean reward:", mean_100ep_reward, "Num episodes:", len(episode_rewards))
    return mean_100ep_reward
